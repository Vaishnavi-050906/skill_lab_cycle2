# %%
'''write a progam to build a calculater 
1.which perform addition subtraction, multiplication and division.
2.take a number and operater inside a try block.
3.user accept block to handle invalid input,zerodivision,unsupported.'''

try:
    n=int(input("number1:"))
    m=int(input("number2:"))
#operation 
    a=n+m
    b=n-m
    c=n*m
    d=n/m
    
    print("addition is:",a) 
    print("addition is:",b)
    print("multiplication is:",c)
    print("division is",d)

except zeroDivisionError:

        print("m cannot be zero(0),kindly try again with other number.")
        print("the solution is done , closing the program")

# %%
def a(m+n):
    return m+n
def b(c-d):
    return c-d
def e(g*h):
    return g*h
def f(i/j):
    if j==0:
        raise ZeroDivisionError("Zero is not acceptable. Try again with another value") 
    return
