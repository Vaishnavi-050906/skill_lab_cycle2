# %%
try:
    n=int(input("Number1:"))
    m=int(input("number2:"))
    res=n/m
    print("result is:",res)
except:
    print("M cannot be zero (0),kindly try again with different number")
print("the solution is done,Hence closing the program")

# %%
try:
    n=int(input("Number1:"))
    m=int(input("number2:"))
    res=n/m
    print("result is:",res)
except ZeroDivisionError:
    print("M cannot be zero (0),kindly try again with different number")
print("The program is done,Hence closing it")

# %%
print("M cannot be zero (0),kindly try again with different number")
print("The program is done,Hence closing it")try:
    n=int(input("Number1:"))
    m=int(input("number2:"))
    res=n/m
    print("result is:",res)

#indexing exception
    my_list=[1,2,3] #3 variables we have taken or declare
    a=int(input("Enter the index position"))
    print(my_list[a])
except ZeroDivisionError:

# %%
try:
    n=int(input("Number1:"))
    m=int(input("number2:"))
    res=n/m
    print(1/0)
except ZeroDivisionError:
    print("M cannot be zero (0),kindly try again with different number")
finally:
    print("the solution is done,Hence closing the program")
