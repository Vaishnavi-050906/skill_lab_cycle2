# %%
f=open("msg.txt","r")
content=f.read()
print(content)
f.close()
# Out:
# this is my trainning class.

# %%
f=open("msg.txt","r")
content=f.read(7)
print(content)
f.close()
# Out:
# this is

# %%
with open("python.txt","w")as f:
    f.write("This is my new file.")
    f.write("\n Today we are learning file handling and exception handling.")
